# %%
import requests
import pandas as pd
from config import GOOGLE_BOOKS_API_KEY

# %%
#https://books.google.com.tr/books?id=AKJjDwAAQBAJ&hl=tr&redir_esc=y

# %%
BOOK_ID ="AKJjDwAAQBAJ"
url ="https://www.googleapis.com/books/v1/volumes/"+BOOK_ID+"?key="+GOOGLE_BOOKS_API_KEY+"&part=snippet,id&order=date&maxResults=1000"

# %%
print(url)
# Out:
# https://www.googleapis.com/books/v1/volumes/AKJjDwAAQBAJ?key=AIzaSyA6YaEYN9x_belFJOxE_kRO4rZ0gtykWzg&part=snippet,id&order=date&maxResults=1000

# %%
response=requests.get(url).json()

# %%
response
# Out:
# {'kind': 'books#volume',
#  'id': 'AKJjDwAAQBAJ',
#  'etag': 'Ckm8MC9j/JA',
#  'selfLink': 'https://www.googleapis.com/books/v1/volumes/AKJjDwAAQBAJ',
#  'volumeInfo': {'title': 'Sherlock Holmes',
#   'subtitle': 'Zümrüt Taç',
#   'authors': ['Sir Arthur Conan Doyle'],
#   'publisher': 'Maşuk Kitap',
# ...

# %%
response["volumeInfo"]["subtitle"]
#kitap başlığı
# Out:
# 'Zümrüt Taç'

# %%
#kitap yazarı
response["volumeInfo"]["authors"]
# Out:
# ['Sir Arthur Conan Doyle']

# %%
response["volumeInfo"]['publisher']
# Out:
# 'Maşuk Kitap'

# %%
BOOK_ID = "William Shakespeare"
url ="https://www.googleapis.com/books/v1/volumes?q="+BOOK_ID+"&key="+GOOGLE_BOOKS_API_KEY+"&maxResults=8"

# %%
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 902,
#  'items': [{'kind': 'books#volume',
#    'id': 'fQ9kDwAAQBAJ',
#    'etag': 'XPZGX2FwOyE',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/fQ9kDwAAQBAJ',
#    'volumeInfo': {'title': 'HAMLET',
#     'subtitle': 'Including The Classic Biography: The Life of William Shakespeare',
#     'authors': ['William Shakespeare'],
#     'publisher': 'e-artnow',
#     'publishedDate': '2017-12-06',
# ...

# %%
if 'items' in response:
    for item in response['items']:
        volume_info = item.get('volumeInfo', {})  # Use get to handle cases where 'volumeInfo' is not present
        desc = volume_info.get('description', 'No description available')
        authors = volume_info.get('authors', ['No authors available'])

        print(f"Özet: {desc}")
        print(f"Yazarlar: {', '.join(authors)}")
        print("\n---\n")
else:
    print("No 'items' found in the response.")
# Out:
# Özet: The Tragedy of Hamlet, Prince of Denmark, written by William Shakespeare between 1599 and 1601, is set in Denmark and recounts how Prince Hamlet exacts revenge on his uncle Claudius, who murdered the King, takes the throne and marries Hamlet's mother. Life of William Shakespeare is a biography of William Shakespeare by the eminent critic Sidney Lee. This book was one of the first major biographies of the Bard of Avon. It was published in 1898, based on the article contributed to the Dictionary of National Biography. William Shakespeare (1564 – 1616) was an English poet and playwright, widely regarded as the greatest writer in the English language and the world's pre-eminent dramatist. He is often called England's national poet and the "Bard of Avon". His extant works, including some collaborations, consist of about 38 plays, 154 sonnets, two long narrative poems, and a few other verses, the authorship of some of which is uncertain. Sir Sidney Lee (1859 – 1926) was an English bi
# ...

# %%
#for dloop in reponse
for book in response["items"]:
    if book['kind'] == 'books#volume':
        book_title = book['volumeInfo']['title']
      
        book_id = book['id']
        page_count = book['volumeInfo']['pageCount']
        upload_date = book['volumeInfo']['publishedDate']
        upload_date = str(upload_date).split("T")[0]


        print(book_title)
        print(book_id)
        print(page_count)
        print(upload_date)
        print("\n")
# Out:
# HAMLET
# fQ9kDwAAQBAJ
# 1256
# 2017-12-06
#
#
# The Life of the Author: William Shakespeare
# q0k3EAAAQBAJ
# 192
# 2021-07-06
#
#
# Nine Lives of William Shakespeare
# JQdHAQAAQBAJ
# 227
# 2011-10-06
#
#
# William Shakespeare
# CSrrkKclA8cC
# 561
# 2009
#
#
# The Complete Works of William Shakespeare
# jipZDwAAQBAJ
# 1392
# 2014-10-01
#
#
# The Plays of William Shakespeare in Ten Volumes
# hAcrAAAAYAAJ
# 1544
# 1778
#
#
# The Works of William Shakespeare
# mSkXAAAAYAAJ
# 628
# 1872
#
#
# The Works of William Shakespeare
# EW8oAAAAYAAJ
# 522
# 1868

# %%
import requests
import pandas as pd
import time
from config import GOOGLE_BOOKS_API_KEY

# %%
#kitapsayısıbulma
def get_book_count(book_id, book_api_key):
    book_url = "https://www.googleapis.com/books/v1/volumes/"+book_id+"?key="+book_api_key+"&part=snippet,id&order=date&maxResults=1000"
    book_response = requests.get(book_url).json()

    return book_response['volumeInfo']['pageCount']

# %%
def get_books(df, search_book, google_api_key):
    # Make API call
    url ="https://www.googleapis.com/books/v1/volumes?q="+search_book+"&key="+google_api_key+"&maxResults=8"    
    response = requests.get(url).json()
    time.sleep(3)

    if 'items' in response:
        for book in response['items']:
            if book['kind'] == 'books#volume':
                book_title = book['volumeInfo']['title']
                book_id = book['id']
                upload_date = book['volumeInfo']['publishedDate']
                upload_date = str(upload_date).split("T")[0]

                page_count = get_book_count(book_id, google_api_key)

                # Save in pandas df
                df = df._append({
                    "id": book_id,
                    "title": book_title,
                   
                    "publishedDate": upload_date,
                    "pageCount": page_count
                }, ignore_index=True)

    return df

# %%
SEARCH_BOOK = "William Shakespeare"

df = pd.DataFrame(columns=["id", "title", "publishedDate", "pageCount"])
books = get_books(df, SEARCH_BOOK, GOOGLE_BOOKS_API_KEY)

# %%
books.head()
# Out:
#              id                                        title publishedDate  \
# 0  fQ9kDwAAQBAJ                                       HAMLET    2017-12-06
# 1  q0k3EAAAQBAJ  The Life of the Author: William Shakespeare    2021-07-06
# 2  JQdHAQAAQBAJ            Nine Lives of William Shakespeare    2011-10-06
# 3  CSrrkKclA8cC                          William Shakespeare          2009
# 4  jipZDwAAQBAJ    The Complete Works of William Shakespeare    2014-10-01
#
#   pageCount
# 0      1256
# 1       192
# 2       215
# 3       550
# 4      1392
